# %%
from IPython.display import Image
from IPython.display import clear_output
from IPython.display import FileLink, FileLinks
import matplotlib.pyplot as plt
import pandas        as pd
import os
import time

from IPython.display import HTML
styles = """
<style>
    h1 {
        margin-top: 0 !important;
    }
    h2 {
        margin-top: 0 !important;
    }
</style>
"""
HTML(styles)
display(HTML(styles))

# %% [markdown]
# <img src="img/python-logo-master-flat.png" alt="Python Logo" style="width: 120px; float: right; margin: 0 0 10px 10px;" />
#
# ## Introduction to Python with Application in Bioinformatics
#
# ### Nanjiang Shu
#
# #### 2024-07-15 (Day 1)

# %% [markdown]
# ### Who we are
#
# Nanjiang Shu            |    Can Hou           |    Yike Gong         |  Lei Liu            |  Yihan Hu
# :-------------------:|:-------------------:|:-------------------:|:-------------------:|:--------:
# <img src="img/nanjiang-shu.jpg" alt="Drawing" style="width: 160px;"/>|<img src="img/can-hou.png" alt="Drawing" style="width: 160px;"/>|<img src="img/yike-gong.png" alt="Drawing" style="width: 160px;"/>|<img src="img/lei-liu.png" alt="Drawing" style="width: 160px;"/>|<img src="img/yihan-hu.jpg" alt="Drawing" style="width: 160px;"/>

# %% [markdown]
# Note: Every student say their name and where they are from

# %% [markdown]
# # Who you are
#
# Introduce yourself!

# %% [markdown]
# ### Who you are - research experience
#
# <img src="img/research_fields.png" alt="research fields" style="width: 1300px;"/>
#
# __The above figure was generated by Python__

# %% [markdown]
# ### Who you are - programming experience
# <p align="center">
# <img src="img/programming_experience.png" alt="research fields" style="width: 500px;"/>
# </p>
#
# __The above figure was generated by Python__

# %% [markdown]
# ### Who you are - bioinformatics experience
# <p align="center">
# <img src="img/bioinformatics_experience.png" alt="research fields" style="width: 650px;"/>
# </p>
#
# __The above figure was generated by Python__

# %% [markdown]
# ## Schedule
#
# <img src="../img/schedule.png" alt="Drawing" width="1400px;"/>

# %% [markdown]
# ### Practical issues
#
# - Course website:
# https://python-bioinfo.bioshu.se/ (username: `python`, password: `python2024`)
# - Format: one lection + one exercise
# - Use Jupyter notebooks for lectures
# - Important concepts will be repeated and extented in the next few days
# - Schedule times are approximate
# - Ask TAs if you encounter any problems during the course
# - Discuss with your classmates when doing exercises

# %% [markdown]
# ## Check
#
# - Have you read the precourse materials: https://python-bioinfo.bioshu.se/precourse.html?
# - Have you managed to install Python and necessary packages on your laptop?
# - Have you managed to run the test script https://python-bioinfo.bioshu.se/downloads/test.py in the terminal with
#   ```
#   python test.py
#   ```
#
# __It is recommended to setup the Python environment on your own laptop.__
# - Our TAs can help you setting up the Python environment during the breaks.

# %% [markdown]
# ## Note: What is programming?
#
# Wikipedia:
#
# "Computer programming is the process of building and designing an executable computer program for accomplishing a specific computing task"

# %% [markdown]
# ## Why programming?
#
# ### Typical workflow
#
# 1. Get data
# 2. Clean, transform data in spreadsheet
# 3. Copy-paste, copy-paste, copy-paste
# 4. Run analysis & export results
# 7. Realise the columns were not sorted correctly
# 8. Go back to step 2, Repeat

# %% [markdown]
# <img src="img/picard.jpg" alt="Drawing" style="width: 200px;floating: left;"/>

# %% [markdown]
# __With programming, you can automate some manual procesures__

# %% [markdown]
# Give an example of plot, you may create a plot by Excel or other advanced plotting software, however, if you want to create hundreds or thousands of such plots,

# %% [markdown]
# ## Why Python?
#
# * Readability and simplicity

# %% [markdown]
# * Note: Python is a high-level, interpreted programming language known for its readability and simplicity

# %%
# In Python
print("Hi, Python!")

# %%
/* In C++ */
#include <iostream>

int main() {
    std::cout << "Hi, Python!" << std::endl;
    return 0;
}

# %% [markdown]
# ## Why Python?
#
# #### Popularity, which means extensive libraries and strong community support
#
# <img src="../img/language-ranking.png" alt="Drawing" width="1200px;"/>
# <p style="font-size: 12px;">source: tiobe.com/tiobe-index</p>

# %% [markdown]
# * Note: * It is widely used in web-development, data analysis, artificial intellegience, scientific computing and more

# %% [markdown]
# ## Why Python?
#
# #### Integration and Extensibility

# %% [markdown]
# - Integration with C.
#     - Numpy, which builds the fundatation for the popular deep learning package - Tensorflow
# - `pandas` to read, manipulate and write Excel files programmtically

# %% [markdown]
# ### Python is under active development
#
# |Old versions|Python 3|
# |--- |--- |
# |Python 1.0 - January 1994|Python 3.0 - December 3, 2008|
# |Python 1.0 - January 1994|Python 3.1 - June 27, 2009|
# |Python 1.2 - April 10, 1995|Python 3.2 - February 20, 2011|
# |Python 1.3 - October 12, 1995|Python 3.3 - September 29, 2012|
# |Python 1.4 - October 25, 1996|Python 3.4 - March 16, 2014|
# |Python 1.5 - December 31, 1997|Python 3.5 - September 13, 2015|
# |Python 1.6 - September 5, 2000|Python 3.6 - December 23, 2016|
# |Python 2.0 - October 16, 2000|Python 3.7 - June 27, 2018|
# |Python 2.1 - April 17, 2001|Python 3.8 - October 14, 2019|
# |Python 2.2 - December 21, 2001|Python 3.9 - October 5, 2020|
# |Python 2.3 - July 29, 2003|Python 3.10 - October 4, 2021|
# |Python 2.4 - November 30, 2004|Python 3.11 - October 24, 2022|
# |Python 2.5 - September 19, 2006|Python 3.12 - October 2, 2023|
# |Python 2.6 - October 1, 2008||
# |Python 2.7 - July 3, 2010||

# %% [markdown]
# Note: Python release a minor version once a year

# %% [markdown]
# <h2>Course content</h2>
#
# - Core concepts about Python syntax: Data types, blocks and indentation, variable scoping, iteration, functions, methods and arguments
# - Different ways to control program flow using loops and conditional tests
# - Writing functions and scripts and making them usable
# - Reading and writing files
# - Code packaging and Python libraries
# - How to work with biological data using external libraries.
# - How to use AI to assist your programming and to help with futrue study

# %% [markdown]
# ### Learning outcomes
# - Use variables and exlain how operators work
# - Process data using loops
# - Separate data using if/else statements
# - Use Python to read and write files
# - Understand the difference between functions and methods
# - Be able to read the documentation for built-in functions and methods
# - Write basic functions
# - Use pandas for basic data processing and plotting
# - Create stand-alone Python programs for data processing
# - Describe your own approach to a coding task
# - Know how to further develop your skills in Python after the course

# %% [markdown]
# ## Day 1
#
# - __Session 1__:
#   - Data Types, variables, and their basic operations
# - __Session 2__:
#   - Built-in functions and operations
# - __Session 3__: (after lunch)
#   - Loops
# - __Session 4__:
#   - Conditional Statements: if/else

# %% [markdown]
# ## Session 1: Data types, variables, and their basic operations

# %% [markdown]
# Not: Lets start with some of the simplest Python code

# %%
print(1 + 1)
print("Hello Python")

# %%
a = 1 + 1
print(a)
a = "Hello Python"
print(a)

# %% [markdown]
# - Fixed values, e.g. `1` and `Hello Python`, in the Python code are called `liternals`
# - Liternals are immutable
# - The name `a` that holds the value is called a `variable`

# %% [markdown]
# Note: Liternals are called Liternals because they are liternally written in the code and are immutable.

# %% [markdown]
# ### Types of Liternals
# - Numeric Literals
#     - Integer, e.g. `42`, `-5`, `1000`
#     - Float, e.g. `3.14`, `-0.002`, `10.0`
# - String Literals
#     - Represent sequences of characters, e.g. `Hello Python`, `ATCG`
# - Boolean Literals
#     - Only two values: `True` and `False`.
# - None Literal
#     - Represents the absence of a value or a null value. It has the value `None`

# %% [markdown]
# #### 1. The literal's type determines the variable's type
#
# <br>
#
# #### 2. In Python, the data type is inferred automatically

# %%
a = 1
a = "ATCG"
a = True
a = None

# %%
# Can you tell the types of them?
sequence_length = 200
scale = 2.5
gene_id = "ABC12345"
is_DNA = False

# %% [markdown]
# #### Use `type()` function to determine the type of a variable

# %%
type(None)

# %% [markdown]
# ### Use `print()` function to display the value of a variable

# %%
sequence_length = "askdfjaslkdgjaskldgjaskldfja"
print(sequence_length)

# %% [markdown]
# ### Note: Python has also designed a few data types that can hold collections of variables

# %% [markdown]
# ### Collection data types
# - List and Tuple
# - Set
# - Dictionary

# %% [markdown]
# ### List and Tuple
# - List and tuple are ordered collection of elements

# %%
seq_len = 200
seq_lens = [100, 150, 200] # a list 
print(seq_lens)

# %%
seq_lens = (100, 150, 200) # a tuple
print(seq_lens)

# %% [markdown]
# #### Elements in a list or tuple can be homogeneous (all the same type) or heterogeneous (different types), and they can be of any data type.

# %%
li = [100, 150, None, "ATCG", 3.1415, seq_len, seq_lens]
li

# %% [markdown]
# ### Difference of List and Tuple
# - List is mutable
# - Tuple is immutable

# %%
li_seqlens = [100, 150, 200]
tu_seqlens = (100, 150, 200)

# %%
li_seqlens[1] = 500
print(li_seqlens)

# %%
tu_seqlens[1] = 500

# %% [markdown]
# ### Set
# - Set is an unordered collection of unique elements

# %%
gene_ids = {"TP53", "COX2", "EGFR", "COX2" "MTOR"} # a set
gene_ids

# %%
# set is unordered
gene_ids = {"1", "2", "3", "4", "5"}
for e in gene_ids:
    print(e)

# %%
# set has unique element
gene_ids = {"1", "1", "2", "2", "3"}
print(gene_ids)

# %% [markdown]
# ### Difference of Set and List
# - Set is unordered, list is ordered
# - Set has unique elements, list can have duplicated elements
# - Set is unindexed (s[idx) does not work), list is indexed (li[idx])
# - Set is generally faster than list in membership checking.

# %%
mylist = ["1", "2", "3", "4", "5"]
myset = {"1", "2", "3", "4", "5"}

# %%
for e in mylist:
    print(e)

# %%
for e in myset:
    print(e)

# %% [markdown]
# ### Dictionary
# - A dictionary is an unordered, mutable collection of key-value pairs.
# - Each key in a dictionary must be unique and immutable (e.g., strings, numbers, or tuples), while the values associated with keys can be of any data type and can be duplicated.

# %%
sequence_info = {  # a dictionary
    "gene": "TP53",
    "species": "Homo sapiens",
    "length": 2000
}
sequence_info

# %% [markdown]
# #### Note: Dictionary provides a convenient, efficient and flexible way to handel complexy and large scale data. We will talk more about it in the coming days.

# %% [markdown]
# ### What operations can we do with different values?
#
# That depends on their type

# %% [markdown]
# ## Integer operations
# - Addition: 2 + 3 = 5
# - Subtraction: 7 - 4 = 3
# - Multiplication: 6 * 3 = 18
# - Division: 8 / 2 = 4.0
# - Modulus (remainder): 5 % 2 = 1
# - Exponent: 2 ** 3 = 8

# %%
8/2

# %% [markdown]
# ## Float operations
# - Addition: 1.5 + 2.3 = 3.8
# - Subtraction: 5.5 - 1.2 = 4.3
# - Multiplication: 3.2 * 2.1 = 6.72
# - Division: 7.5 / 2.5 = 3.0

# %%
1 + 1.5

# %% [markdown]
# ### Warning: keep in mind the precision limitations of floating-point arithmetic.

# %%
result = 0.1 + 0.2 - 0.3
print(result)

# %%
print(result == 0.0)

# %%
print((result - 0.0) < 1e-6)

# %%
import math
result = 0.1 + 0.2 - 0.3
print(result)
print(math.isclose(result, 0.0, abs_tol=1e-10))

# %%
# An example showing the difference of calculations caused by precision
# Initialize variables
a_large_number = 1000000.0
increment = 0.000001
iterations = 1000000

# Add increment to the large number iteratively
for _ in range(iterations):
    a_large_number += increment

# Directly compute expected number
expected_value = 1000000.0 + increment * iterations

# Print results
print("After addition: ", a_large_number)
print("Expected value: ", expected_value)
print("Difference: ", expected_value - a_large_number)

# %% [markdown]
# ## String operations
# - Concatenation: "Homo " + "Sapiens" = "Homo Sapiens"
# - Repeating: "GC" * 3 = "GCGCGC"
# - Slicing: "protein"[1:4] = "rot"
# - Length: len("ATCG") -> 4
# - Methods:
#   - .upper(), .lower()
#   - .replace("A", "T")

# %%
seq_lens[1:3]

# %% [markdown]
# ## Boolean operations
#
# - Logical AND: True and False = False
# - Logical OR: True or False = True
# - Logical NOT: not True = False
# - Comparison:
#   - Equal: 2 == 2 = True
#   - Not Equal: 2 != 3 = True
#   - Greater Than: 5 > 3 = True
#   - Less Than: 5 < 3 = False

# %%
5 > 3

# %% [markdown]
# ## Data type conversion
# - Convert Float to Integer: int(3.14) = 3
# - Convert Integer to String: str(5) = "5"
# - Convert String to Float: float("3.14") = 3.14

# %%
type(int("56"))

# %% [markdown]
# #### When you run operations on different data types, an underlying data type conversion has been made

# %%
1 + 1.5

# %%
# Guess what will be the result for this?
1 + False

# %% [markdown]
# ### How to correctly name a variable
#
#
# <img src="img/variable_name.png" alt="Drawing" style="width: 500px;"/>
#
# __Special characters are NOT allowed:__: \+ - * $ % ; : , ? ! { } ( ) < > “ ‘ | \ / @
#
# ### Examples:
#
# | __Valid__  |         __Invalid__  |
# |        -   | -                       |
# | Var\_name        |           2save  |
# | \_total |  \*important  |
# | aReallyLongName |                        Special%  |
# | with\_digit\_2 |         With  &nbsp; spaces  |

# %% [markdown]
# #### What about `dkfsjdsklut`

# %% [markdown]
# - well, this is a valid name, but NOT recommended`

# %% [markdown]
# ## Reserved keywords
#
# <img src="img/python_keywords.png" alt="Drawing" style="width: 600px;"/>
#
#
# <b>These words can not be used as variable names</b>

# %%
gobalName

# %% [markdown]
# ### Best practices for naming variables in Python
# - Use descriptive names:
#   - Choose names that describe the purpose of the variable.
#   - Example: Use `gene_id` instead of `gi`.
#
# - Follow naming conventions for Python, e.g., snake_case:
#   - Example: Use `gene_name`, `sequence_length`, `sample_id`.
#
# - Prefix Booleans with 'is', 'has', 'can', etc:
#   - Example: `is_high_quality`, `has_mutations`.

# %% [markdown]
# ## Summary
# - Literals define values and can have different types (strings, integers, floats, boolean etc).
# - Variables are identified by a name and are used to store a value.
# - Values can be collected in lists, tuples, sets, and dictionaries.
# - The operation that can be performed on a certain value depends on its type.
# - Name your variables using descriptive words without special characters and reserved keywords.

# %% [markdown]
# ## Exercise time
#
#
# ### Day 1, Exercise 1 (~30 min)
# - Link: https://python-bioinfo.bioshu.se/exercises.html
#
# ___
#
# ### Short break after the exercise

# %% [markdown]
# ## NOTE!
#
# ### How to get help?
#
# - [Google](https://www.google.com/) and [Stack overflow](https://stackoverflow.com/) are your best friends!
# - Official [python documentation](https://docs.python.org/3/)
# - Ask your neighbour
# - Ask us

# %% [markdown]
# ## Session 2: Built-In functions and operations

# %% [markdown]
# Note: Do you still remember the print() and type() function we have used in the previous session? These are Python built-in functions

# %%
# display the value with print()
result = "ACCCG" * 5
print(result)

# %%
# show the type of value with type()
print(type(result))

# %%
# convert float value to string value with str()
str(2.5)

# %% [markdown]
# ## Python standard library
# https://docs.python.org/3.9/library/functions.html
#
# <img src="img/built-in_functions.png" alt="Drawing" style="width: 900px;"/>

# %% [markdown]
# Note: the object for len(), sum(), min(), max() should be iterable

# %% [markdown]
# ## len()

# %%
sequence = "ATGCTACGATaCG"
len(sequence)

# %%
seq_lens = [100, 200, 300]
len(seq_lens)

# %%
# can you get the length of an integer
len(3)

# %% [markdown]
# ## sum()

# %%
read_counts = [1500, 2000, 1750, 2250, 1900, 2500]
print("total_reads:", sum(read_counts))

# %% [markdown]
# ## min() and max()

# %%
expression_levels =  [2.5, 3.6, 4.2, 5.0, 3.8, 3.8, 9.5, 100.1]
print("Max expression level:", max(expression_levels))
print("Min expression level:", min(expression_levels))

# %%
print("Average expression level: ", sum(expression_levels)/len(expression_levels))

# %% [markdown]
# ## sorted()

# %%
read_counts = [1500, 2000, 1750, 2250, 1900, 2500]
sorted_read_counts = sorted(read_counts, reverse=True)
print(sorted_read_counts)

# %% [markdown]
# <img src="img/built-in_functions.png" alt="Drawing" style="width: 600px;"/>
#
# - With these built-in functions, one can easily manupultate data to achieve your purpose
# - Further reading: https://docs.python.org/3.9/library/functions.html

# %% [markdown]
# ## More on operations
#
# <img src="img/operations.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# One of the most common operations in programming is comparison, in Python we can use the following operators to carry out various comparisons

# %% [markdown]
# ## Comparison operators
#
# <img src="img/comparison_operator.png" alt="Drawing" style="width: 600px;"/>
#
# Can be used on int, float, str, and bool. Outputs a boolean.

# %%
seq_len1 = 150
seq_len2 = 181

seq_len1 = seq_len2

# %% [markdown]
# ## Logical operators
#
# <img src="img/logical_operator.png" alt="Drawing" style="width: 600px;"/>

# %%
freq1 = 0.51
freq2 = 1.5

not True

# %% [markdown]
# ## Membership operators
#
# <img src="img/membership_operator.png" alt="Drawing" style="width: 600px;"/>

# %%
gene_ids = ["TP53", "COX2", "EGFR", "MTOR"] # a set

"TP531" in not gene_ids

# %% [markdown]
# ### Order of precedence
#
# There is an order of precedence for all operators:
#
# <img src="img/order_of_precedence.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# ### A word of caution when using operators

# %%
length = 500
species = "Mouse"
read_count = 100
# I want to evaluate the condition that length is larger than 300 or species is Mouse, 
# and read_count is larger than 200
# Expected value: False
length > 300 or species == "Mouse" and read_count > 200

# %%
(length > 300 or species == "Mouse") and read_count > 200

# %% [markdown]
# - Always remember that __and__ takes precedence over __or__ in logical expressions.
# - Use parentheses `()` to make your intended grouping explicit and improve readability.

# %%
# BEWARE!
x = 5
y = 8

# xx == 6 or xxx == 6 or x > 2
x > 42 or (y < 7 and xx > 1000)

# %% [markdown]
# __Python does short-circuit evaluation of operators__

# %% [markdown]
# ## More on operations for Lists and Strings
#
# __Lists__ and __strings__ are an ORDERED collection of elements where every element can be accessed through an index.
#
# <img src="img/operations_on_sequences.png" alt="Drawing" style="width: 600px;"/>

# %%
mylist = [1, 2, 3, 4, 5, 6, 7, 8, 9]
mylist[4]

# %%
mylist[1:3]

# %%
mylist[0:9:2] # [start, stop, step]

# %%
mylist[3:] # from 4th position to the end

# %%
mylist[:5] # from the beginning to the 5th position

# %%
mylist[::1] # the same as mylist[:] , or mylist[::] or mylist[::1]

# %% [markdown]
# ### Use of the negative index
#
# ```
#               list = [1,   2,   3 ,  4 ,   5]
# positive indeces      0    1    2    3     4
# negative indeces     -5   -4   -3   -2    -1
# ```
#
# Equation: `positive_index = len(li) + negative_index`

# %%
mylist = [1, 2, 3, 4, 5]
mylist[-1] # return the last element, equivalent to mylist[8]
mylist[len(mylist)-1]

# %%
# What will be the result for this?
mylist[::-1]

# %% [markdown]
# ### When the step is negative, it changes the direction

# %% [markdown]
# #### Similar operations for Strings

# %%
mystr = "123456789"
print("mystr[2] \t= ", mystr[2] )
print("mystr[1:3] \t= ", mystr[1:3])
print("mystr[0:9:2] \t= ", mystr[0:9:2])
print("mystr[3:] \t= ", mystr[3:])
print("mystr[:5] \t= ", mystr[:5])
print("mystr[:] \t= ", mystr[:])
print("mystr[-1] \t= ", mystr[-1])
print("mystr[::-1] \t= ", mystr[::-1])

# %% [markdown]
# ## Mutable vs Immutable objects
# Mutable objects can be altered after creation, while immutable objects can't.
#
# | __Immutable objects__ | __Mutable objects__ |
# |-----------------------|---------------------|
# | int                   | list                |
# | float                 | set                 |
# | bool                  | dict                |
# | str                   |                     |
# | tuple                 |                     |

# %%
# list is mutable
mylist = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(mylist)
mylist[2] = 7
print(mylist)

# %%
# string is immutable
mystr = "123456789"
mystr[2] = "7"

# %% [markdown]
# Note: You may wonder about the data types int, float and bool, are they really immutable?
# why we say int is immutable even we it's value can be changed?
# This is because when we assign a new value to `a`, a new value has been created.
# we can show it by `id()` (

# %% [markdown]
# ### Are `int`, `float` and `bool` immutable?

# %%
a = 5
print("a=", a)
a = 6
print("a=", a)

# %%
# id(var) returns the memory address of var.
a = 5
print("memory address of a = ", id(a), ", value of a = ", a)
a = 6
print("memory address of a = ", id(a), ", value of a = ", a)

# %%
mylist = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print("memory address of mylist = ", id(mylist), ", value of mylist = ", mylist)
mylist[2] = 7
print("memory address of mylist = ", id(mylist), ", value of mylist = ", mylist)

# %% [markdown]
# Note: there are many operations for the mutable sequences, such as list, set and dictionary. We will talk about it more in the comming days. Here we just show a few examples for Lists

# %% [markdown]
# ### More operations on Lists
#
# <img src="img/operations_on_mutable_sequences.png" alt="Drawing" style="width: 500px;"/>

# %%
mylist = [1, 2, 3, 4, 5, 6, 7, 8, 9]
mylist.append(15)
print(mylist)

# %%
mylist.remove(15)
print(mylist)

# %%
del mylist[2]
print(mylist)

# %% [markdown]
# ## Summary
#
# - The Python standard library has many built-in functions that regularly used
# - Operators are used to carry out computations on different values
# - Three types of operators that return a boolean: comparison, logical, and membership
# - Order of precedence is crucial - use parentheses `()` for clarity!
# - Mutable object can be changed after creation while immutable objects cannot be changed

# %% [markdown]
# ## Day 1, Exercise 2 (~30 min)
# - Link: https://python-bioinfo.bioshu.se/exercises.html
#
# ___
# ## Break after the exercise
# ___
#
# ## Day 1, quiz
# - Link: https://python-bioinfo.bioshu.se/quiz.html
# ___
# ## Lunch

# %% [markdown]
# ## Afternoon session
# ___
# ### 1. Loops
# - Exercise 3 of Day 1
# ___
# ##### Break
# ___
# ### 2. if/else statement
# - Exercise 4 of Day 1

# %% [markdown]
# ## Session 3: Loops in Python

# %%
gene_ids = ["TP53", "COX2", "EGFR", "MTOR"]
# How do we print all IDs, one per line?

# %%
print(gene_ids[0])
print(gene_ids[1])
print(gene_ids[2])
print(gene_ids[3])

# %%
gene_ids = ["TP53", "COX2", "EGFR", "MTOR"]

for gene_id in gene_ids:
    print(gene_id)

# %% [markdown]
# Note the INDENT of the __for__ loop

# %% [markdown]
# ## Indentation is crucial in Python
# - Blocks of code are defined by their indentation level.
# - Typically, a tab or four spaces are used for each indentation level, but consistency within a block is the key.

# %%
for gene_id in gene_ids:
    print(gene_id)

# %%
for gene_id in gene_ids:
    print("==ID==")
    print(gene_id)
    print(1)

# %%
for gene_id in gene_ids:
       print("==ID==")
       print(gene_id)

# %%
for gene_id in gene_ids:
        print("==ID==")
    print(gene_id)

# %%
for gene_id in gene_ids:
	print("==ID==")
    print(gene_id)

# %% [markdown]
# #### Don't mix tabs and spaces, although it's allowed.

# %%
# firs show
for gene_id in gene_ids:
    print(gene_id)

# then show, two lines with the same indentation will be considered as the same block
for gene_id in gene_ids:
    print("==ID==")
    print(gene_id)

# then show indentation with 8 white spaces are also valid, but 4 spaces are commonly used in Python
for gene_id in gene_ids:
        print("==ID==")
        print(gene_id)

# then show indentation must be consistent, otherwise error or unexpected result may occur
for gene_id in gene_ids:
        print("==ID==")
    print(gene_id)

# %% [markdown]
# ## Types of loops

# %% [markdown]
# #### `For` loop

# %%
gene_ids = ["TP53", "COX2", "EGFR", "MTOR"]

for gene_id in gene_ids:

# %% [markdown]
# #### `While` loop

# %%
gene_ids = ["TP53", "COX2", "EGFR", "MTOR"]

i = 0
while i < len(gene_ids):
    print(i, gene_ids[i])
    i += 1

print("== When loop ends, i =", i)

# %% [markdown]
# ### Types of loops
#
# __`For` loop__
#
# Is a control flow statement that performs a fixed operation over a known amount of steps.
#
# __`While` loop__
#
# Is a control flow statement that allows code to be executed repeatedly based on a given Boolean condition.
#
# <br></br>
#
# __Which one to use?__
#
# `For` loops better for simple iterations over lists and other iterable objects
#
# `While` loops are more flexible and can iterate an unspecified number of times

# %% [markdown]
# ### Examples of `while` loop

# %% [markdown]
# Note: this loop will break at either the end of list or when it encounter a gene ID started with 'E', that is, it will only print two elements
#
# If I want to select print all elements that are not started with 'E'
#
# I should write in this way
# ```python
# while i < len(gene_ids):
#     if not gene_ids[i].startswith("E"):
#         print(gene_ids[i])
#     i += 1
# ```

# %%
gene_ids = ["TP53", "COX2", "EGFR", "MTOR"]

i = 0
while i < len(gene_ids) and not gene_ids[i].startswith("E"):
    print(gene_ids[i])
    i += 1

print("== When loop ends, i =", i)

# %% [markdown]
# Note: there is one built-in function called `range()` which is especially useful for the for loop

# %% [markdown]
# ## The `range()` function

# %%
for i in range(5):
    process_seq(i)

# %%
file_basename = "dnaseq"
for i in range(10):
    seqfile = file_basename + "_" + str(i) + ".fa"
    print("Analyzing " + seqfile)

# %% [markdown]
# ## Summary
# - Python has two types of loops: `for` loops and `while` loops.
# - Loops can be used with any iterable types and objects to perform repeated tasks.
# - `for` loops are better suited for iterating over lists and other iterable objects when the number of iterations is known or finite.
# - `while` loops offer more flexibility and can iterate an unspecified number of times, as they continue until a specified condition is no longer true.
# - The `range()` function is useful for programming with loops.

# %% [markdown]
# ## Day 1,  Exercise3  (~30 minutes)
# - Link: https://python-bioinfo.bioshu.se/exercises.html
# ___
#
# ### 10 min break after the exercise

# %% [markdown]
# ## Session 4: Conditional statement

# %% [markdown]
# - Conditional statements allow decision-making in a program.
# - Python uses `if`, `elif`, and `else` for conditionals.

# %%
if condition1:
    # executed if condition1 is True
elif condition2:
    # executed if condition1 is False and condition2 is True
else:
    # executed if both condition1 and condition2 are False

# %% [markdown]
# <img src="img/if_else_statement.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# ### The `if` statement
# - The `if` statement is the fundamental control statement that allows Python to execute based on a condition.

# %%
dna_sequence = "AGTCTNCG"
if 'N' in dna_sequence:
    print("invalid DNA sequence.")
    print("compicated")

# %% [markdown]
# ### The `else` statement
# - An `else` statement follows an if and defines what to do if the if condition is not met.

# %%
expression_level = 35
if expression_level > 0:
    print("Gene is overexpressed.")
else:
    print("Gene is not overexpressed.")

# %% [markdown]
# ### The `elif` statement
# - The `elif` (shortname for "else if") allows chaining of conditional statements.

# %%
expression_level = 35
if expression_level > 100:
    print("Gene is overexpressed.")
elif expression_level > 30 and expression_level <= 100:
    print("Gene is expressed.")
else:
    print("Gene is underexpressed.")

# %% [markdown]
# ### Nested conditional statements
# - Nested conditions occur when a conditional statement is placed inside another conditional statement.
# - It allows for more specific and granular control based on multiple criteria.

# %%
# Use nested conditionals to categorize genetic variants based on multiple attributes.
genotype = "AG"
phenotype = "expressed"
if genotype == "AG":
    # Only check phenotype if genotype is "AG"
    if phenotype == "expressed":
        print("Variant " + genotype + " is active and expressed.")
    else:
        print("Variant " + genotype + " is active but not expressed.")
else:
    print("Variant " + genotype + " is a non-target variant.")

# %% [markdown]
# ## Summary
#
# - `if`, `elif`, and `else` are powerful tools for controlling program logic.
# - `if`, `elif`, and `else` statements can be nested. However, it is advisable to avoid excessive nesting, as this can make the code difficult to read and maintain.

# %% [markdown]
# ## Day 1, Exercise 4 (~30min)
# - Link: https://python-bioinfo.bioshu.se/exercises.html
# ___
#
# # End of Day 1
